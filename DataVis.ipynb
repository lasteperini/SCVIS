# %%
print("Hello World")
# Out:
# Hello World

# %%
#Seaborn è una libreria che dipende da pandas, numpy e matplotilib, per usarla vanno importati tutti
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#LONG-FORM DATA

flights.head() 

# Si nota la differenza tra ogni mese di un anno
#Colonne=variabili
#righe=osservazioni
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
#ESEMPIO FLIGHT DATASET LONG-FORM DATA
flights = sns.load_dataset("flights")
sns.relplot(data=flights, x="year", y="passengers", hue="month", kind="line") 
#nei long-form dataset le colonne devono essere esplicitamente assegnate alle variabili degli assi

# %%
#VISUALIZZAZIONE DEI WIDE-FORM DATA, righe contengono il n° di passeggeri per ogni mese, righe diverse=anni diversi
flights_wide.head()
#si nota la differenza per ogni anno
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
# WIDE-FORM DATA
flights_wide = flights.pivot(index="year", columns="month", values="passengers")
sns.relplot(data=flights_wide, kind="line")

# %%
# DATASET IN FORMA DISORDINATA
anagrams = sns.load_dataset("anagrams")
anagrams.head()
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6
# 3       4  divided     5   7.0     5
# 4       5  divided     4   5.0     8

# %%
# Va trasformato in un long o wide form dataset 
# si usa il metodo pandas.DataFrame.melt()
anagrams_long = anagrams.melt(id_vars=["subidr", "attnr"], var_name="solutions", value_name="score")
anagrams_long.head()
# Out:
#    subidr    attnr solutions  score
# 0       1  divided      num1    2.0
# 1       2  divided      num1    3.0
# 2       3  divided      num1    3.0
# 3       4  divided      num1    5.0
# 4       5  divided      num1    4.0

# %%
# Con Pandas ci sono degli operatori di raggruppamento e divisione per i dati 
flights_avg = flights.groupby("year").mean() # Groupby()
sns.relplot(data=flights_avg, x="year", y="passengers", kind="line")
#questo grafico consente di vedere il numero di passeggeri annuali e come questo trend cambia

# %%
#it’s possible to pass vectors of data directly as arguments to x, y, and other plotting variables. 
#If these vectors are pandas objects, the name attribute will be used to label the plot:
year = flights_avg.index
passengers = flights_avg["passengers"]
sns.relplot(x=year, y=passengers, kind="line")
# il risultato è identico ma è cambiato il modo di creare il grafico stesso, vengono passati gli attributi alle variabili

# %% [markdown]
# ESEMPI

# %%
#ESEMPIO PENGUINS DATASET
#HISTPLOT 
penguins = sns.load_dataset("penguins") #import del dataset penguins da seaborn
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
#KDEPLOT
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Density'>

# %%
#SCATTERPLOT, HISTPLOT
f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species", ax=axs[0])
sns.histplot(data=penguins, x="species", hue="species", shrink=.8, alpha=.8,legend=False, ax=axs[1])
f.tight_layout()

# %% [markdown]
# COLORI

# %% [markdown]
# In seaborn ci sono delle palette di colori che si possono utilizzare: deep, muted, pastel, bright, dark, e colorblind.

# %%
prova= pd.ExcelFile("Documents/prova.xlsx")
dataset=prova.parse()
print(dataset)
# Out:
#        Nomi Genere Colore
# 0      Sara      F   Rosa
# 1  Caterina      F   Rosa
# 2      Luca      M    Blu
# 3  Giovanna      F   Rosa
# 4   Massimo      M    Blu
# 5  Eleonora      F   Rosa
# 6  Beatrice      F   Rosa

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
#sns.set_style("whitegrid")
#sns.color_palette(palette = None, n_colors = 5, desat = None)
#sns.set_palette("Greens")
#sns.set_style("white")
#sns.color_palette()

# %%
sns.histplot(data=dataset, x="Genere", hue='Genere')
#sns.set_palette("Set1", 8, .75)
sns.color_palette()
plt.show()

# %%
colors= ["light pink","azure"]
palette=sns.xkcd_palette(colors)
sns.histplot(data=dataset, x="Genere", hue='Genere' )
sns.set_palette(palette)
plt.show()
